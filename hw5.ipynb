# %% [markdown]
# ### Упражнение 1. Умножение списков
#
# Даны три списка целых числе `A`, `B` и `C`. Элементы списка `D` являются произведениями элементов списков `A`, `B` и `C`, стоящих на соответствующих позициях. Перепишите ниже приведенный код с использванием генераторов списков и `zip`.
#
# Элементы списков подаются на вход программе через пробел, каждый список в отдельной строке.
#
# Элементы списка `D` череез пробел так же, как выходные данные.
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font> |
# | :--- | :--- |
# | <font size=3>1 1 1<br>1 2 3<br>2 3 4</font> | <font size=3>2 6 12</font> |

# %%
a = [int(elem) for elem in input().split()]
b = [int(elem) for elem in input().split()]
c = [int(elem) for elem in input().split()]
D = [a*b*c for a,b,c in zip(a,b,c)]
print(D)
# Out:
# 1 1 1
# 1 2 3
# 2 3 4
# [2, 6, 12]

# %% [markdown]
# # Упражнение 2. Координаты точек
#
# Зависимость координат от времени дана в виде четырех списков одинаковой длины: `T`, `X`, `Y`, `Z`. Требуется получить список из строк вида `"t=... x=... y=... z=..."`. На вход программе подается число элементов в оригинальных 4-х списках. Используйте `zip`.
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font> |
# | :--- | :--- |
# | <font size=3>2</font> | <font size=3>['t=0.0 x=2.0 y=0.0 z=0.0', 't=5.0 x=1.2682724604973217e-06 y=0.0015926529164868282 z=0.5']</font> |
# | <font size=3>3</font> | <font size=3>['t=0.0 x=2.0 y=0.0 z=0.0', 't=3.3333333333333335 x=0.5009198006443802 y=0.8665558000562658 z=0.3333333333333333', 't=6.666666666666667 x=0.49816209077769047 y=-0.8649616828896994 z=0.6666666666666666']</font> |
# | <font size=3>5</font> | <font size=3>['t=0.0 x=2.0 y=0.0 z=0.0', 't=2.0 x=1.3096228130570242 y=0.95085946050647 z=0.2', 't=4.0 x=0.1917325727306899 y=0.5888155619677953 z=0.4', 't=6.0 x=0.18986111787600068 y=-0.5862379991700271 z=0.6000000000000001', 't=8.0 x=1.3065924679690988 y=-0.9518408788156858 z=0.8']</font> |

# %%
import math
PI = 3.14
N = int(input())
T = [10 / N * i for i in range(N)]
X = [1 + math.cos(2 * PI / N * i) for i in range(N)]
Y = [math.sin(2 * PI / N * i) for i in range(N)]
Z = [1 / N * i for i in range(N)]
m = ['t='+str(t)+' x='+str(x)+' y= '+str(y)+' z= '+str(z) for t,x,y,z in zip(T,X,Y,Z)]

print(T)
print(X)
print(m)
# Out:
# 2
# [0.0, 5.0]
# [2.0, 1.2682724604973217e-06]
# ['t=0.0 x=2.0 y= 0.0 z= 0.0', 't=5.0 x=1.2682724604973217e-06 y= 0.0015926529164868282 z= 0.5']

# %% [markdown]
# ### Упражнение 3. Транспонирование группы списков
#
# Даны 5 списков из 3 элементов каждый. Сделайте из них 3 кортежа из 5 элементов так, чтобы в первом кортеже были первые элементы исходных списков, во втором кортеже - вторые элементы исходных списков и т. д.. Используйте `zip` и раскройте zip-объект с помощью множественного присваивания, как в примере 1 из lab5.

# %%
a = [1, 2, 3]
b = [4, 5, 6]
c = [7, 8, 9]
d = [10, 11, 12]
e = [13, 14, 15]
for A,B,C,D,E in zip(a, b, c, d,e):
    print(' '.join(map(str,[A, B, C, D, E])))
# Out:
# 1 4 7 10 13
# 2 5 8 11 14
# 3 6 9 12 15

# %% [markdown]
# ### Упражнение 4. Общие элементы 2 списков
#
# На вход подаются два списка целых чисел, выведите все их общие элементы. Элементы списков подаются на вход программе через пробел, каждый список в отдельной строке. Распечатайте общие элементы списков через пробел.
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font> |
# | :--- | :--- |
# | <font size=3>1 1 1<br>1 2 3</font> | <font size=3>1</font> |

# %%
a = set(input().split())
b = set(input().split())
d = a&b
print(' '.join(d))
#print (a)
#print (b)
#print([e for e in a if e in b])
# Out:
# 1 1 1
# 1 2 3
# 1

# %% [markdown]
# ### Упражнение 5. Список учеников
#
# Часть учеников из трех девятых классов ушла в колледжи, а часть поступила в два 10-х класса. У завуча Марьи Ивановны есть списки с фамилиями учеников бывших 9-х и новых 10-х классов. Получите для Марьи Ивановны список фамилий поступивших в колледжи учеников, упорядоченный в алфавитном порядке. Гарантируется, что в параллели нет однофамильцев и что в нее не пришли новенькие.
#
# Фамилии учеников из одного класса передаются через пробел. В первых трех строках - ученики 9-х классов, в 4-й и 5-й строках - ученики 10-х классов.
#
# Используйте операции над множествами.
#
# | <font size=3>Входные данные</font> | <font size=3>Выходные данные</font> |
# | :--- | :--- |
# | <font size=3>Иванов Петров Сидорова<br>Иваненко Петренко<br>Сидоренко<br>Петров Петренко<br>Иванов</font> | <font size=3>Иваненко Сидоренко Сидорова</font> |

# %% [markdown]
# a = set(input())
# b = set(input())
# c = set(input())
# d = set(input())
# e = set(input())
# f = a+b+c-d-e
# print(f)

# %%
a = set(input().split())
b = set(input().split())
c = set(input().split())
d = set(input().split())
e = set(input().split())
v = (a | b | c) - (d | e)
w = ' '.join(v)

print(w)
# Out:
# Иванов Петров Сидорова
# Иваненко Петренко
# Сидоренко
# Петров Петренко
# Иванов
# Сидорова Сидоренко Иваненко

# %%
a = [2, [3, 4]]
b, [c, d] = a  # OK
print('\nb, c, d:', b, c, d)
[e, [f, g]] = a  # OK
print('\ne, f, g:', e, f, g)
h, (i, j) = a  # OK
print('\nh, i, j:', h, i, j)
k, l, m = a  # ERROR
# Out:
# b, c, d: 2 3 4
#
# e, f, g: 2 3 4
#
# h, i, j: 2 3 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ceb123f67b5c> in <module>
#       6 h, (i, j) = a  # OK
#       7 print('\nh, i, j:', h, i, j)
# ----> 8 k, l, m = a  # ERROR
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# ### Упражнение 6. Калькулятор для множеств
# Напишите калькулятор для множеств и реализуйте его в виде функции. Первым аргументом функции должна быть строка, содержащая команды, которые требуется выполнить над множествами. Инструкция содержит имена множеств, обозначенные английскими заглавными буквами, и бинарные операции над ними. Возможные бинарные операции:
#
# 1) пересечение множеств: `&`
#
# 2) объединение множеств: `|`
#
# 3) разность множеств: `-`
#
# 4) симметричная разность: `^`
#
# В инструкции операнды и операторы разделяются пробелами, инструкция не содержит скобок. Обращаю ваше внимание на то, что одно множетво может встречаться в инструкции несколько раз. На число множеств, которые используются в инструкции не накладывается ограничений.
#
# **Операции выполняются слева направо, то есть нормальный приоритет операций игнорируется.**
#
# Следующие аргументы функции - список множеств, в котором они в первый раз появляются в инструкции. Реализуйте программу так, чтобы в качестве аргументов функции можно было передавать последовательности (списки, кортежи, строки).
#
# В решении должен составляться словарь, в котором ключами служат операнды из инструкции, а значениями - переданные аргументы. При составлении словаря должен использоваться `zip`.
#
# Реализуйте разбиение инструкции на операнды о операторы в виде отдельной функции.
#
# Протестируйте реализованную функцию на множествах символов.
#
# Входные данные:
#
# - первая строка содержит инструкцию,
#
# - вторая строка представляет собой несколько строк, разделенных пробелами. Каждая строка - это одно из множеств символов.
#
# | <font size=3>входные данные</font> | <font size=3>выходные данные</font> |
# | :---: | :---: |
# | <font size=3>$A ~|~ B$<br>ab bc</font> | <font size=3>{'a', 'b', 'c'}</font> |
# | <font size=3>$ A ~ \text{&}~ B ~ |~ C $<br>ab bc cd</font> | <font size=3>{'b', 'c', 'd'}</font> |
# | <font size=3>$A~ |~ B ~\text{&}~ C$<br>bc cd ab</font> | <font size=3>{'b'}</font> |
#
#
#
# | <font size=3>$A~\hat{}~A$<br>ab</font> | <font size=3>{}</font> |

# %%
def f(a):
    d = {a[1::2]:a[::2]}
    return f
    
a = input().split()
#b = input().split()
print(f(a))
# Out:
# A & B
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-af9349360231> in <module>
#       6 a = input().split()
#       7 #b = input().split()
# ----> 8 print(f(a))
#
# <ipython-input-40-af9349360231> in f(a)
#       1 def f(a):
# ----> 2     d = {a[1::2]:a[::2]}
#       3     return f
#       4
#       5
#
# TypeError: unhashable type: 'list'

# %%
a = [input('input instruction ').split()]
b = [input('input sets ')]
#def splitting(a):
for i in a:
    c.append(i)
print(c)


#def intersection()
#if | in a:
# Out:
# input instruction A | b
# input sets ab bc
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4f037e451fc6> in <module>
#       3 #def splitting(a):
#       4 for i in a:
# ----> 5     c.append(i)
#       6 print(c)
#       7
#
# AttributeError: 'generator' object has no attribute 'append'

# %% [markdown]
# ### Упражнение 7. Запись в файл
#
# Откройте файл unicode2000.txt на запись и запишите в него подряд символы unicode с 33 по 2000. Используйте встроенную функцию [`chr()`](https://docs.python.org/3/library/functions.html#chr).
#
# >В этой и следующих задачах используйте контекстные менеджеры

# %%
with open('unicode2000.txt', 'w') as f:
    f.write(str([chr(e) for e in range(33,2000)]))

# %% [markdown]
# ### Упражнение 8. Дописывание в конец файла
#
# 1. Создайте файл hw5.8.1.txt и запишите в него строку `"I am the first file!"`.
#
# 2. Создайте файл hw5.8.2 с текстом `"I am the second file!"`.
#
# 3. Считайте содержимое первого файла и допишите его в конец второго файл в обратном порядке.

# %%
text = i
with open('hw5.8.1.txt','w') as f:
    f.write("I am the first file!")
with open('hw5.8.2.txt','w') as g:
    g.write("I am the second file!")
with open('hw5.8.1.txt','r') as f:
    l = f.read()
with open('hw5.8.2.txt','a') as g:
    g.write(l)
with open('hw5.8.2.txt','r') as g:
    m = g.read()
print(m)
# Out:
# I am the second file!I am the first file!

# %% [markdown]
# ### Упражнение 9. Считывание данных из файла
# Скачайте с github.com файл hw5.9.txt и полужите в одну папку с файлом, в котором будет решение задачи.
# Команда для скачивания:
# ```bash
# wget https://raw.githubusercontent.com/mipt-cs/python-biocad/master/files/hw5.9.txt
# ```
#
# Заполнен строками следующего вида: `"n x y"`, где `n` - целое число, `x` и `y` - вещественные числа. Считайте данные из файла и получите три списка: со значениями `n`, `x` и `y`.
#
# Для удаления из конца строки символов переноса строки `\n` используйте строковый метод [`str.rstrip()`](https://docs.python.org/3/library/stdtypes.html#str.rstrip).

# %%
with open('hw5.9.txt','r') as f:
    l = f.readlines()
h = [m.rstrip('\n') for m in l]
nxy = [[float(e) for e in l.split()] for l in h]
n,x,y = zip(*nxy)
    
 
print(n)
print(x)
# Out:
# (-2.0, 8.0, -3.0, -2.0, -2.0, -7.0, -9.0, -4.0, 6.0, -6.0, 7.0, 10.0, 3.0, 1.0, -7.0, 7.0, -8.0, -10.0, -9.0, 4.0, -5.0, -1.0, -8.0, -8.0, 6.0, 1.0, -5.0, -6.0, -1.0, 2.0, -6.0, -8.0, 7.0, 5.0, 9.0, 10.0, 2.0, 5.0, 9.0, 4.0, -10.0, -3.0, -7.0, 8.0, -1.0, 2.0, -7.0, -10.0, -5.0, -4.0, 1.0, -3.0, 8.0, -4.0, -3.0, 9.0, -8.0, -4.0, 6.0, 3.0, -5.0, 2.0, 5.0, 10.0, -7.0, -10.0, 9.0, 1.0, 4.0, 2.0, -7.0, 5.0, 8.0, -6.0, 10.0, -6.0, 1.0, 0.0, -3.0, 3.0, 8.0, -2.0, -10.0, 2.0, -1.0, 6.0, 0.0, -9.0, -1.0, 10.0, -6.0, 7.0, -10.0, -7.0, 8.0, 9.0, 6.0, 4.0, -4.0, -6.0, -1.0, 1.0, 8.0, 2.0, -5.0, -8.0, -6.0, -10.0, 1.0, 5.0, -2.0, -7.0, -9.0, -3.0, 8.0, -9.0, -4.0, 3.0, 2.0, 3.0, 2.0, 3.0, -9.0, -9.0, -2.0, 8.0, -2.0, -10.0, -4.0, 7.0, -2.0, 5.0, 4.0, 3.0, -6.0, 0.0, 6.0, 9.0, -9.0, -7.0, 0.0, 2.0, 10.0, 7.0, -2.0, 4.0, -3.0, 6.0, 0.0, 8.0, 2.0, -3.0, -7.0, -6.0, 4.0, 9.0, 1.0, 5.0, -3.0, -2.0, 5.0, -5.0, 4.0, 1.0, 10.0, 9.0, 6.0, -4.0, -5.0, -1.0, -3.0, 9.0, -3.0, -8.0, 5.0, 7.0, 1.0, 10.0, 3.0, 
# ...

# %% [markdown]
# ### Упражнение 10. Циклический сдвиг
#
# Осуществите циклический сдвиг вправо символов строки. Циклический сдвиг вправо на 1 - преобразование строки, в котором все символы кроме последнего сдвигаются на одну позицию вправо, а крайний справа попадает в начало строки. Циклический сдвиг на `k` - это последовательное выполнение циклических сдвигов на 1.
#
# Задача решается в одну строчку с помощью срезов.
#
# На вход подается строка из символов, и (через пробел) число позиций, на которые следует осуществить сдвиг.
#
# | <font size=3>входные данные</font> | <font size=3>выходные данные</font> |
# | :---: | :---: |
# | <font size=3>abcd 1</font> | <font size=3>dabc</font> |
# | <font size=3>abcd 3</font> | <font size=3>bcda</font> |
# | <font size=3>d 4</font> | <font size=3>d</font> |
# | <font size=3>abcd 4</font> | <font size=3>abcd</font> |
# | <font size=3>abcd 5</font> | <font size=3>dabc</font> |

# %%
a = (input())
k = int(input())
print(a[k%len(a)-len(a):]+a[:k%len(a)-len(a)])
# Out:
# abcd
# 2
# cdab

# %% [markdown]
# ### Упражнение 11.
#
# Вася хочет узнать, какую оценку он получит в четверти по информатике. Учитель придерживается следующей системы: вычисляется среднее арифметическое всех оценок в журнале, и ставится ближайшая целая оценка, не превосходящая среднего арифметического.
#
# При этом если у школьника есть двойка, а следующая за ней оценка – не двойка, то двойка считается закрытой, и при вычислении среднего арифметического не учитывается.
#
# Вводится десять натуральных чисел от 2 до 5 через пробел – оценки Васи.
#
# Выведите натуральное число (от 2 до 5) – его четвертную оценку.
#
# | Входные данные | Выходные данные |
# |:--- |:--- |
# | 2 5 2 5 2 5 2 5 2 5 | 5     |
# | 2 2 2 2 2 2 2 2 2 5 | 2     |
# | 5 5 5 5 5 5 5 5 5 2 | 4     |

# %%
a = [int(e) for e in input().split()]
b = []
for i in range(len(a)-1):
    if a[i] > 2 or (a[i] == 2 and a[i+1] == 2):
        print('a[i] ', a[i])
        b.append(a[i])
       
print(a,len(a))
print((sum(b)+a[len(a)-1])//(len(b)+1))
# Out:
# 2 3 4 5 2 2 3 4 5
# a[i]  3
# a[i]  4
# a[i]  5
# a[i]  2
# a[i]  3
# a[i]  4
# [2, 3, 4, 5, 2, 2, 3, 4, 5] 9
# 3

# %%
a = [int(e) for e in input().split()]
b = []
b = [i for i in range(len(a)-1) if a[i] > 2 or (a[i] == 2 and a[i+1] == 2)]
print(b)    
       # print('a[i] ', a[i])
        #b.append(a[i])
       
print(a,len(a))
print((sum(b)+a[len(a)-1])//(len(b)+1))
# Out:
# 2 3 2 3 2 3
# [1, 3]
# [2, 3, 2, 3, 2, 3] 6
# 2

# %% [markdown]
# ### Упражнение 12.
# Для изучения пассажиропотока в метро было записано время входа и время выхода в метро каждого пассажира. На основании этих данных определите, сколько пассажиров было в метро в некоторый заданный момент времени $T$.
#
# Программа получает на вход число пассажиров $N$. Далее в $N$ строчках записано время входа $A_i$ и время выхода $B_i$ каждого пассажира ($A_i < B_i$). Время задается в минутах от начала работы метрополитена.
#
# В следующей строке дано время $T$.
#
# Выведите одно число: количество пассажиров в момент времени $T$. Если какой-то пассажир в момент $T$ входит или выходит, то его тоже необходимо посчитать.
#
#
# | Входные данные  | Выходные данные |
# | :--- | :--- |
# | 4     | 3     |
# | 3 12  |       |
# | 8 9   |       |
# | 5 10  |       |
# | 10 12 |       |
# | 10    |       |

# %%
N = int(input('введите число пассажиров  ')) #введите число пассажиров
#b = []
m = 0 #текущее число пассажиров
b = [[int(e) for e in input().split()] for t in range(N)]
print(b)
T = int(input())
for i in range(len(b)):
    if (b[i][0] <= T) and (b[i][1] >= T):
        m += 1
print(m)
# Out:
# введите число пассажиров  4
# 3 12
# 8 9
# 5 10
# 10 12
# [[3, 12], [8, 9], [5, 10], [10, 12]]
# 10
# 3
